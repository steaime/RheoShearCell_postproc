# %%
import os
import bisect
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt
from RSCpp import IOfuncs as iof
from RSCpp import RheoConfig as rconf
from RSCpp import RheoCorr as rcorr
from RSCpp import FTrheo as ft
from RSCpp import AnalysisFuncs as af
from RSCpp import SharedFunctions as sf
from pathlib import Path

import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger = logging.getLogger('matplotlib')
logger.setLevel(logging.WARNING)
logging.info('ShearCell postproc tutorial started')
# Out:
# INFO:root:ShearCell postproc tutorial started

# %% [markdown]
# # Shear cell rheology post processing
#
# This tutorial explains how to load and analyze rheology experiments done with the shear cell
#
# ### 1. Locate data and reconstruct rheology protocol
#
# Data should be in the output folder of the rheology program. Three types of files should be in there:
#
# - ```Config_Rheo.ini```: the configuration file used by the rheology program
# - ```expLog.txt```: the log file with the list of the intervals that have been generated by the rheology program
# - A list of file with name structure ```PREFIX[a][_POS/NEG].txt```, with:
#   - ```PREFIX``` a prefix specified in the ```Name``` field of ```expLog.txt```
#   - ```[a]``` a character suffix that counts how many times that interval has been repeated
#   - ```[_POS/NEG]``` eventually, another suffix to distinguish positive and negative ramps
#
# Information on rheology protocol is lodaded in ```RheoConfig.RheoProtocol``` object using the function
#
# ```python
# rconf.RheoProtocol(config_folder, config_fname='Config_Rheo.ini', explog_fname='expLog.txt')
# ```

# %%
froot = r'D:\Data\Emanuele\251119\Dati\rheo\002'
rheo_protocol = rconf.RheoProtocol(froot)
print(rheo_protocol)
# Out:
# INFO:root:429 rows read from expLog file D:\Data\Emanuele\251119\Dati\rheo\002\expLog.txt
# INFO:root:expLog file updated with 430 output file paths
# <RheoProtocol (198 intervals)>

# %% [markdown]
# This object can be used to reconstruct a dataset with each interval's setting, including the output file path, using
#
# ```python
# RheoProtocol.LoadExpLog(force_reload=False, load_fnames=True)
# ```
#
# **NOTE**: this file path is reconstructed based on the assumption that the file naming hasn't changed. This assumption can be wrong for old data.
#
# The program checks if the reconstructed file path corresponds to a file that really exists.

# %%
rheo_explog = rheo_protocol.LoadExpLog()
rheo_explog
# Out:
#     ID     Time Type                                   Name  Force  \
# 0    1  4.50291    0     01_FrequencySweep_highfreq_001_000  <err>
# 1    2  10.9692    0     01_FrequencySweep_highfreq_001_001  <err>
# 2    3  20.4107    0     01_FrequencySweep_highfreq_001_002  <err>
# 3    4  34.1766    0     01_FrequencySweep_highfreq_001_003  <err>
# 4    5  54.2715    0     01_FrequencySweep_highfreq_001_004  <err>
# ..  ..      ...  ...                                    ...    ...
# 423  2  710.074    0  198_FrequencySweep_mediumfreq_002_001  <err>
# 424  3  1341.62    0  198_FrequencySweep_mediumfreq_002_002  <err>
# 425  4  2342.42    0  198_FrequencySweep_mediumfreq_002_003  <err>
# 426  5  3928.41    0  198_FrequencySweep_mediumfreq_002_004  <err>
# 427  6  2146.96    0  198_FrequencySweep_mediumfreq_002_005  <err>
#
#     Displacement        Speed    Period Offset RelOffset  ... StartPos  \
# 0          0.005      0.07339  0.428068      0         1  ...  4.27334
# 1          0.005         0.05  0.628319      0         1  ...  4.27334
# 2          0.005    0.0340646  0.922245      0         1  ...  4.27334
# 3          0.005    0.0232079   1.35367      0         1  ...  4.27334
# 4          0.005    0.0158114   1.98692      0         1  ...  4.27334
# ..           ...          ...       ...    ...       ...  ...      ...
# 423        0.005  0.000315479   99.5818      0         1  ...  4.29386
# 424        0.005  0.000199054   157.826      0         1  ...  4.29385
# 425        0.005  0.000125594   250.138      0         1  ...  4.29385
# 426        0.005  7.92447e-05   396.442      0         1  ...  4.29386
# 427        0.005        5e-05   628.319      0         1  ...  4.29385
#
#       EndPos    StartForce      EndForce Trigger Active Axis StrainControlled  \
# 0    4.27334    0.00174566    0.00119175       0      1    1                1
# 1    4.27334   0.000772118    0.00216529       0      1    1                1
# 2    4.27333   0.000570696   0.000369274       0      1    1                1
# 3    4.27335    0.00166173   0.000990326       0      1    1                1
# 4    4.27334    0.00166173  -5.03555e-05       0      1    1                1
# ..       ...           ...           ...     ...    ...  ...              ...
# 423  4.29386   -0.00097354  -0.000688192       0      1    1                1
# 424  4.29385  -0.000251778   -0.00176244       0      1    1                1
# 425  4.29386   -0.00146031   -0.00159459       0      1    1                1
# 426  4.29386   -0.00097354  -0.000570696       0      1    1                1
# 427  4.29384  -0.000738548  -0.000553911       0      1    1                1
#
#                                               FilePath FilePath_exists
# 0    D:\Data\Emanuele\251119\Dati\rheo\002\01_Frequ...            True
# 1    D:\Data\Emanuele\251119\Dati\rheo\002\01_Frequ...            True
# 2    D:\Data\Emanuele\251119\Dati\rheo\002\01_Frequ...            True
# 3    D:\Data\Emanuele\251119\Dati\rheo\002\01_Frequ...            True
# 4    D:\Data\Emanuele\251119\Dati\rheo\002\01_Frequ...            True
# ..                                                 ...             ...
# 423  D:\Data\Emanuele\251119\Dati\rheo\002\197_Freq...           False
# 424  D:\Data\Emanuele\251119\Dati\rheo\002\198_Freq...            True
# 425  D:\Data\Emanuele\251119\Dati\rheo\002\198_Freq...            True
# 426  D:\Data\Emanuele\251119\Dati\rheo\002\198_Freq...            True
# 427  D:\Data\Emanuele\251119\Dati\rheo\002\198_Freq...            True
#
# [428 rows x 25 columns]

# %% [markdown]
# The result is a ```pandas.DataFrame```, with a list of columns

# %%
rheo_explog.columns
# Out:
# Index(['ID', 'Time', 'Type', 'Name', 'Force', 'Displacement', 'Speed',
#        'Period', 'Offset', 'RelOffset', 'Phase', 'Duration', 'StartTime',
#        'StartedOn', 'EndedOn', 'StartPos', 'EndPos', 'StartForce', 'EndForce',
#        'Trigger', 'Active', 'Axis', 'StrainControlled', 'FilePath',
#        'FilePath_exists'],
#       dtype='object')

# %% [markdown]
# Each column is a ```pandas.Series```

# %%
rheo_explog['Duration']
# Out:
# 0      4.28068
# 1      6.28319
# 2      9.22245
# 3      13.5367
# 4      19.8692
#         ...
# 423    398.327
# 424    631.306
# 425    1000.55
# 426    1585.77
# 427    2513.27
# Name: Duration, Length: 428, dtype: object

# %% [markdown]
# Explog data can be accessed using standard methods

# %%
float(rheo_explog['Duration'][0])
# Out:
# 4.28068

# %%
duration_nparr = rheo_explog['Duration'].to_numpy(dtype=float)
duration_nparr[0]
# Out:
# 4.28068

# %% [markdown]
# Dataframes can be filtered also. This filters all constant-speed measurements (```Type==4```) with moving small motor (```AxisID==1```):

# %%
rheo_explog[(rheo_explog['Type'] == '4') & (rheo_explog['Axis'] == '1')]
# Out:
#       ID     Time Type                        Name  Force Displacement  Speed  \
# 20     4  357.649    4   03_Osr_FlowCurve_0010_000  <err>            3  0.005
# 21     4  957.774    4   03_Osr_FlowCurve_0010_000  <err>            3  0.005
# 50    19     2615    4   18_Osr_FlowCurve_0020_000  <err>            3   0.01
# 51    19  2915.12    4   18_Osr_FlowCurve_0020_000  <err>            3   0.01
# 80    34   2452.2    4   33_Osr_FlowCurve_0030_000  <err>            3  0.015
# 81    34  2652.32    4   33_Osr_FlowCurve_0030_000  <err>            3  0.015
# 110   49  4062.59    4   48_Osr_FlowCurve_0040_000  <err>            3   0.02
# 111   49  4212.72    4   48_Osr_FlowCurve_0040_000  <err>            3   0.02
# 138   63  958.862    4   62_Osr_FlowCurve_0050_000  <err>            3  0.025
# 139   63     1079    4   62_Osr_FlowCurve_0050_000  <err>            3  0.025
# 164   76  3454.25    4   75_Osr_FlowCurve_0060_000  <err>            3   0.03
# 165   76  3554.38    4   75_Osr_FlowCurve_0060_000  <err>            3   0.03
# 190   89  527.035    4   88_Osr_FlowCurve_0070_000  <err>            3  0.035
# 191   89  612.878    4   88_Osr_FlowCurve_0070_000  <err>            3  0.035
# 214  101  402.278    4  100_Osr_FlowCurve_0080_000  <err>            3   0.04
# 215  101  477.404    4  100_Osr_FlowCurve_0080_000  <err>            3   0.04
# 238  113  58.5407    4  112_Osr_FlowCurve_0090_000  <err>            3  0.045
# 239  113  125.335    4  112_Osr_FlowCurve_0090_000  <err>            3  0.045
# 262  125  3592.57    4  124_Osr_FlowCurve_0100_000  <err>            4   0.05
# 263  125  3672.69    4  124_Osr_FlowCurve_0100_000  <err>            4   0.05
#
#     Period Offset RelOffset  ... StartPos   EndPos   StartForce    EndForce  \
# 20   <err>      0         1  ...  4.27334  7.27334  0.000234993  -0.0390088
# 21   <err>      0         1  ...  7.27333  4.27334   -0.0375652   0.0415098
# 50   <err>      0         1  ...  4.28062  7.28062  -0.00122532  -0.0410566
# 51   <err>      0         1  ...  7.28062  4.28062   -0.0412915   0.0427015
# 80   <err>      0         1  ...  4.27408  7.27328  -0.00691549  -0.0422987
# 81   <err>      0         1  ...  7.27329  4.27327   -0.0416272     0.04532
# 110  <err>      0         1  ...  4.27946  7.28022   0.00292062  -0.0424329
# 111  <err>      0         1  ...   7.2802  4.28021   -0.0433729    0.045085
# 138  <err>      0         1  ...  4.26306  7.26227  -0.00555589  -0.0419462
# 139  <err>      0         1  ...  7.26227  4.26226   -0.0412076   0.0439436
# 164  <err>      0         1  ...  4.29496  7.29575   0.00359203  -0.0417783
# 165  <err>      0         1  ...  7.29574  4.29574   -0.0395291   0.0442625
# 190  <err>      0         1  ...  4.28989  7.28989  -0.00184637  -0.0420469
# 191  <err>      0         1  ...   7.2899  4.28988   -0.0397473   0.0458739
# 214  <err>      0         1  ...  4.31564  7.31603   0.00234993  -0.0447996
# 215  <err>      0         1  ...  7.31604  4.31602   -0.0438765   0.0469146
# 238  <err>      0         1  ...  4.29554  7.29478  -0.00584124  -0.0467467
# 239  <err>      0         1  ...  7.29478  4.29477   -0.0447157   0.0496002
# 262  <err>      0         1  ...   4.3205  8.32125    0.0028367  -0.0449339
# 263  <err>      0         1  ...  8.32126  4.32125   -0.0431883   0.0501541
#
#     Trigger Active Axis StrainControlled  \
# 20        0      1    1                1
# 21        0      1    1                1
# 50        0      1    1                1
# 51        0      1    1                1
# 80        0      1    1                1
# 81        0      1    1                1
# 110       0      1    1                1
# 111       0      1    1                1
# 138       0      1    1                1
# 139       0      1    1                1
# 164       0      1    1                1
# 165       0      1    1                1
# 190       0      1    1                1
# 191       0      1    1                1
# 214       0      1    1                1
# 215       0      1    1                1
# 238       0      1    1                1
# 239       0      1    1                1
# 262       0      1    1                1
# 263       0      1    1                1
#
#                                               FilePath FilePath_exists
# 20   D:\Data\Emanuele\251119\Dati\rheo\002\02_Frequ...            True
# 21   D:\Data\Emanuele\251119\Dati\rheo\002\03_Osr_F...            True
# 50   D:\Data\Emanuele\251119\Dati\rheo\002\17_Osr_F...            True
# 51   D:\Data\Emanuele\251119\Dati\rheo\002\18_Osr_F...            True
# 80   D:\Data\Emanuele\251119\Dati\rheo\002\32_Osr_F...            True
# 81   D:\Data\Emanuele\251119\Dati\rheo\002\33_Osr_F...            True
# 110  D:\Data\Emanuele\251119\Dati\rheo\002\47_Osr_F...            True
# 111  D:\Data\Emanuele\251119\Dati\rheo\002\48_Osr_F...            True
# 138  D:\Data\Emanuele\251119\Dati\rheo\002\61_Osr_F...            True
# 139  D:\Data\Emanuele\251119\Dati\rheo\002\62_Osr_F...            True
# 164  D:\Data\Emanuele\251119\Dati\rheo\002\74_Osr_F...            True
# 165  D:\Data\Emanuele\251119\Dati\rheo\002\75_Osr_F...            True
# 190  D:\Data\Emanuele\251119\Dati\rheo\002\87_Osr_F...            True
# 191  D:\Data\Emanuele\251119\Dati\rheo\002\88_Osr_F...            True
# 214  D:\Data\Emanuele\251119\Dati\rheo\002\99_Osr_F...            True
# 215  D:\Data\Emanuele\251119\Dati\rheo\002\100_Osr_...            True
# 238  D:\Data\Emanuele\251119\Dati\rheo\002\111_Osr_...            True
# 239  D:\Data\Emanuele\251119\Dati\rheo\002\112_Osr_...            True
# 262  D:\Data\Emanuele\251119\Dati\rheo\002\123_Osr_...            True
# 263  D:\Data\Emanuele\251119\Dati\rheo\002\124_Osr_...            True
#
# [20 rows x 25 columns]

# %% [markdown]
# ### 2. Read and plot raw data
#
# To load raw output data for a given interval, use:
#
# ```python
# RheoProtocol.ReadRheoData(self, row_index, usecols=(1,2,6), unpack=True, **loadtxt_kwargs)
# ```

# %%
fidx = 20 
#fidx = 40
int_time, int_pos, int_force = rheo_protocol.ReadRheoData(fidx, usecols=(1, 5, 6))
if int_pos is not None:
    fig, ax = plt.subplots()
    ax.plot(int_time, int_force, 'r-', label='force')
    ax.set_xlabel('time')
    ax.set_ylabel('force')
    ax2 = ax.twinx()
    ax2.plot(int_time, int_pos, 'k-', label='position')
    ax2.set_ylabel('position')
    fig.legend()

# %% [markdown]
# ### 3. Batch process multiple files
#
# One useful way to batch process multiple files of one given type is:
#
# ```python
# AnalysisFuncs.BatchProcess(explog_data, filter_type=None, filter_axis=None, filter_name=None, max_num=None, usecols=None, anal_type='count', anal_params={})
# ```
#
# where:
#
# - ```filter_type```, ```filter_axis``` and ```filter_name```, if not ```None```, filter the explog DataFrame based on type, axis and name
# - ```max_num``` eventually limits the number of files to be processed
# - ```usecols``` specifies the columns to be read as $(t, \gamma, \sigma)$. They typically are ```(1,2,6)``` when large motor is used as actuator and small motor is used as strain sensor, or ```(1,5,6)``` when small motor is both applying the strain and measuring the stress
# - ```anal_type```: one of ```['count' (default), 'read', 'plot', 'FT', 'OSR', 'flowcurve', 'avgperiod']```:
#   - ```'count'```: returns the number of result files with the given filter criteria
#   - ```'read'```: returns raw time, displacement and force data
#   - ```'plot'```: plots raw data. Additional parameters to be specified in ```anal_params```:
#       - ```'plot_type'```: type of plot. One of ```['time' (default), 'stressstrain', 'stressrelax']```:
#         - ```'time'```: x: time, left y: displacement, right y: force
#         - ```'stressstrain'```: x: displacement, y: force
#         - ```'stressrelax'```: x: time (log), y: force
#       - ```'fmt'```: format of matplotlib plot. Default is ```'-'```, a solid line
#       - ```'t0'```: reference time, in seconds, to offset raw times (that are relative to first point in the dataset). Default: 0
#   - ```'FT'```: Fourier analysis of oscillatory data. Additional parameters to be specified in ```anal_params```:
#     - ```'nperiods'```: number of oscillations to be analyzed at once. Default: total number of periods - 2
#     - ```'Tres_Step'```: if specified, compute time-dependent moduli by analyzing a limited number of periods, on a sliding window with width ```anal_params['Tres_Nint']``` and step ```'Tres_Step'```, in units of the period. If not set, don't perform time-dependent analysis
#     - ```'Tres_Nint'```: number of oscillations to be analyzed at once in time-dependent analysis. Default: 1
#   - ```'OSR'```: Fourier analysis of orthogonal superposition oscillatory data. Additional parameters to be specified in ```anal_params```:
#     - ```'nperiods'```, ```'Tres_Step'```, ```'Tres_Nint'```: see above
#     - ```'OSRparams'```: ```dict``` with two entries: ```'Period'```, ```'Amp'```, with period and amplitude of the orthogonal oscillation
#     - ```'OSRparam_list'```: eventually, a list of ```dict```, one per interval, containing interval-specific parameters
#   - ```'flowcurve'```: average force on a range of displacements corresponding to steady state to extract flow curve. Averaging displacement range (in mm) is specified as a 2 elements list in ```anal_params['displ_range']=[d_min, d_max]```
#   - ```'avgperiod'```: average strain and stress on a period (typically useful to obtain smooth Lissajous plots out of oscillatory experiments). Additional parameters to be specified in ```anal_params```:
#     - ```'PeriodIdx'```: number of datapoints corresponding to one period
#     - ```'StartIdx'```: start from the Nth datapoint (skipping the ones before). Default: 0
#     - ```'EndIdx'```: skip the last N datapoint. Default: 0
# - ```anal_params```: ```dict``` with additional parameters used by the analysis, as specified above
#
# The function returns:
#
# - if ```anal_type=='count'```: the number of files (```ìnt```)
# - if ```anal_type=='read'```: a list of three-element lists with time, position and force data (```float``` arrays)
# - if ```anal_type=='plot'```: the matplotlib plot (```plt.figure```)
# - if ```anal_type in ['FT', 'OSR']```: a table of FT results, one row per output file, with following columns: ```[Time, Amplitude, Period, Offset, Force_amp, Force_phase, Displ_amp, Displ_phase, k_amp, k_phase, k_real, k_imag, Force_Avg, OSR_Period, OSR_Amp]```, where ```k=-Force/Displacement```, the minus sign accounting for third Newton's law. **NOTE**: if time-dependent analysis is performed (```anal_params['Tres_Step']``` is specified), time-dependent results are automatically exported to an ASCII file with the same name as the raw input file and suffix ```_tresFT``` or ```_tresOSR```, depending on the analysis type.
# - if ```anal_type=='flowcurve'```: two float arrays: ```Speed, AvgForce```
# - if ```anal_type=='avgperiod'```: a 2D array with shape ```[anal_params['PeriodIdx'], 2*num_files+1]```, first column being intra-cycle time, and then period-averaged strain and stress, two columns per raw file

# %% [markdown]
# ### 4a. Application to shear startup experiments

# %%
af.BatchProcess(rheo_explog, filter_type=4, filter_axis=1, anal_type='count')
# Out:
# INFO:root:Auto-detected suffix length: 0 (20 files detected)
# 20

# %%
_ = af.BatchProcess(rheo_explog, filter_type=4, filter_axis=1, anal_type='plot')
# Out:
# INFO:root:Auto-detected suffix length: 0 (20 files detected)

# %%
_ = af.BatchProcess(rheo_explog, filter_type=4, filter_axis=1, anal_type='plot', anal_params={'plot_type': 'stressstrain'})
# Out:
# INFO:root:Auto-detected suffix length: 0 (20 files detected)

# %%
v, F = af.BatchProcess(rheo_explog, filter_type=4, filter_axis=1, anal_type='flowcurve', anal_params={'displ_range':[0.4,0.6]})
fig, ax = plt.subplots()
ax.plot(v[::2], np.abs(0.5*(F[1::2]-F[::2])), 'o:')
ax.set_xscale('log')
ax.set_xlabel('v [mm/s]')
ax.set_ylabel('F [N]')
# Out:
# INFO:root:Auto-detected suffix length: 0 (20 files detected)
# Text(0, 0.5, 'F [N]')

# %% [markdown]
# ### 4b. Application to oscillatory shear experiments

# %%
_ = af.BatchProcess(rheo_explog, filter_type=0, filter_axis=1, filter_name='FrequencySweep', 
                    max_num=21, anal_type='plot', anal_params={'plot_type': 'time'})
# Out:
# WARNING:root:[409/428] : reached limit (21) of files to be processed
# INFO:root:Auto-detected suffix length: 1 (21 files detected)
# WARNING:root:[409/428] : reached limit (21) of files to be processed
# WARNING:root:[409/428] : reached limit (21) of files to be processed

# %%
#tlen = 8
FreqSweep_FTres = af.BatchProcess(rheo_explog, filter_type=0, filter_axis=1, filter_name='FrequencySweep', anal_type='FT', anal_params={'nperiods':1})
np.savetxt(os.path.join(froot, 'FreqSweep_FTres.dat'), FreqSweep_FTres, delimiter='\t', 
    header='time\tamplitude\tperiod\toffset\tF_abs\tF_phase\tx_abs\tx_phase\tk_abs\tk_phase\tk_real\tk_imag\tF_avg\tOSR_period\tOSR_amp')
# Out:
# INFO:root:Auto-detected suffix length: 1 (38 files detected)

# %%
fig, ax = plt.subplots()
ax.plot(2*np.pi/FreqSweep_FTres[:,2], FreqSweep_FTres[:,10], 'ko', label='Gp')
ax.plot(2*np.pi/FreqSweep_FTres[:,2], FreqSweep_FTres[:,11], 'kx', label='Gs')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('w [rad/s]')
ax.set_ylabel('Gp, Gs [N/mm]')
ax.legend()

# %% [markdown]
# ### 4d. Application to Orthogonal Superposition Rheology (OSR) experiments

# %%
osr_intlist = rheo_protocol.FilterIntervals({'type':'STEP_RATE', 'axID':0, 'hasOSR':True})
osr_fnames = rconf.GetIntervalFilenames(osr_intlist, rheo_protocol.config_folder)
OSR_FTres = af.BatchProcess(rheo_explog, anal_type='OSR', anal_params={'nperiods': 1, 'OSRparam_list':[x.OSR for x in rheo_protocol.FilterIntervals()]})
# Out:
# INFO:root:Auto-detected suffix length: 0 (388 files detected)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\32_Osr_FlowCurve_0020_TimeSweep_014_POS.txt (5001 time points): PointsPerWindow=2383 (IndexEdges=[2618, 5001]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=2617 (T=628.3, 4.166666666666667 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\32_Osr_FlowCurve_0020_TimeSweep_014_NEG.txt (5001 time points): PointsPerWindow=2383 (IndexEdges=[2618, 5001]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=2617 (T=628.3, 4.166666666666667 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\47_Osr_FlowCurve_0030_TimeSweep_014_POS.txt (5001 time points): PointsPerWindow=1074 (IndexEdges=[3927, 5001]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=3926 (T=628.3, 6.25 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\47_Osr_FlowCurve_0030_TimeSweep_014_NEG.txt (5001 time points): PointsPerWindow=1074 (IndexEdges=[3927, 5001]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=3926 (T=628.3, 6.25 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\61_Osr_FlowCurve_0040_TimeSweep_013_POS.txt (5001 time points): PointsPerWindow=2285 (IndexEdges=[2716, 5001]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=2715 (T=353.0, 7.6923076923076925 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\61_Osr_FlowCurve_0040_TimeSweep_013_NEG.txt (5001 time points): PointsPerWindow=2285 (IndexEdges=[2716, 5001]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=2715 (T=353.0, 7.6923076923076925 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\145_Osr_FlowCurve_0200_TimeSweep_010_POS.txt (5001 time points): PointsPerWindow=2383 (IndexEdges=[2618, 5001]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=2617 (T=62.83, 41.666666666666664 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\145_Osr_FlowCurve_0200_TimeSweep_010_NEG.txt (5001 time points): PointsPerWindow=2383 (IndexEdges=[2618, 5001]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=2617 (T=62.83, 41.666666666666664 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\146_Osr_FlowCurve_0200_TimeSweep_011_POS.txt (5001 time points): PointsPerWindow=342 (IndexEdges=[4659, 5001]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=4658 (T=111.8, 41.666666666666664 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\146_Osr_FlowCurve_0200_TimeSweep_011_NEG.txt (5001 time points): PointsPerWindow=342 (IndexEdges=[4659, 5001]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=4658 (T=111.8, 41.666666666666664 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\165_Osr_FlowCurve_0700_TimeSweep_008_POS.txt (4767 time points): PointsPerWindow=1450 (IndexEdges=[3317, 4767]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=3316 (T=19.9, 166.66666666666666 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\165_Osr_FlowCurve_0700_TimeSweep_008_NEG.txt (4765 time points): PointsPerWindow=1448 (IndexEdges=[3317, 4765]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=3316 (T=19.9, 166.66666666666666 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\166_Osr_FlowCurve_0700_TimeSweep_009_POS.txt (4901 time points): PointsPerWindow=0 (IndexEdges=[4901, 4901]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=5042 (T=35.3, 142.85714285714286 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\166_Osr_FlowCurve_0700_TimeSweep_009_NEG.txt (4901 time points): PointsPerWindow=0 (IndexEdges=[4901, 4901]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=5042 (T=35.3, 142.85714285714286 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\167_Osr_FlowCurve_0700_TimeSweep_010_POS.txt (4901 time points): PointsPerWindow=0 (IndexEdges=[4901, 4901]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=8975 (T=62.83, 142.85714285714286 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\167_Osr_FlowCurve_0700_TimeSweep_010_NEG.txt (4901 time points): PointsPerWindow=0 (IndexEdges=[4901, 4901]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=8975 (T=62.83, 142.85714285714286 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\168_Osr_FlowCurve_0700_TimeSweep_011_POS.txt (4901 time points): PointsPerWindow=0 (IndexEdges=[4901, 4901]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=15971 (T=111.8, 142.85714285714286 fps)
# WARNING:root:Error processing file D:\Data\Emanuele\251119\Dati\rheo\002\168_Osr_FlowCurve_0700_TimeSweep_011_NEG.txt (4902 time points): PointsPerWindow=0 (IndexEdges=[4902, 4902]), NumPeriods=1 (start: 1.0, len: 1, WindowEdges=(1.0, 2.0)), PointsPerPeriod=15971 (T=111.8, 142.85714285714286 fps)

# %%
fig, ax = plt.subplots()
ax.plot(2*np.pi/OSR_FTres[:,-2], OSR_FTres[:,10], 'ko', label='Gp 1Hz')
ax.plot(2*np.pi/OSR_FTres[:,-2], OSR_FTres[:,11], 'kx', label='Gs 1Hz')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('w [rad/s]')
ax.set_ylabel('Gp, Gs [N/mm]')
ax.legend()
